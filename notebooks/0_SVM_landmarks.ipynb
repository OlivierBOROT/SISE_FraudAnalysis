# %%
import os
import pickle

import mlflow
import mlflow.sklearn
import numpy as np
import pandas as pd
from mlflow.tracking import MlflowClient
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    f1_score,
    make_scorer,
)
from sklearn.model_selection import GridSearchCV, StratifiedKFold

from sklearn.cluster import KMeans

from sklearn.metrics.pairwise import rbf_kernel, linear_kernel

from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler

import pickle

# %% [markdown]
# # Data import and preparation

# %%
# import file
with open("../data/cleaned_data.pkl", "rb") as f:
    df = pickle.load(f)

# %%
train_index = (df["DateTransaction"] >= "2017-02-01") & (
    df["DateTransaction"] <= "2017-08-31"
)
test_index = (df["DateTransaction"] >= "2017-09-01") & (
    df["DateTransaction"] <= "2017-11-30"
)

train = df[train_index]
test = df[test_index]

del train_index, test_index

# Variable to discard
to_discard = ["ZIBZIN", "IDAvisAutorisationCheque", "DateTransaction", "CodeDecision"]

# %%
test = test.drop(columns=to_discard)
train = train.drop(columns=to_discard)

y_train = train["FlagImpaye"]
X_train = train.drop(columns=["FlagImpaye"])
y_test = test["FlagImpaye"]
X_test = test.drop(columns=["FlagImpaye"])

# %% [markdown]
# ## Standardization

# %% [markdown]
# Standardization of quantitative variables (OneHotEncoded variable "JourSemaine" remain unchanged)

# %%
cols_to_keep = ['JourSemaine']
cols_to_scale = X_train.columns.difference(['JourSemaine'])

# %%
X_train
# Out:
#          Montant  VerifianceCPT1  VerifianceCPT2  VerifianceCPT3  D2CB  \
# 0          20.00               0               0               0   551
# 1          20.00               0               0               0   551
# 2          57.64               0               0               0   549
# 3          54.29               1               1               1   267
# 4          26.90               0               0               0   549
# ...          ...             ...             ...             ...   ...
# 3888464   137.90               0               0               0   451
# 3888465    73.76               0               0               0   526
# 3888466    61.21               0               0               0   489
# 3888467    58.90               0               0               0   538
# 3888468    24.99               0               0               0   320
#
#          ScoringFP1  ScoringFP2  ScoringFP3  TauxImpNb_RB  TauxImpNB_CPM  \
# 0          0.000000    0.000000    0.000000     37.186668      52.076034
# 1          0.000000    0.000000    0.000000     48.844716      52.076034
# 2          0.000000    0.000000    0.000000     73.118280      52.076034
# 3          0.000000    0.000000    0.000000    110.056926      53.554234
# 4          0.003769    8.586333    0.001192     45.368313      52.076034
# ...             ...         ...         ...           ...            ...
# 3888464    0.008264    7.010333    0.001799     45.368313      52.076034
# 3888465    0.007380   -8.307757    0.001744    222.222222      52.076034
# 3888466    0.006588   -4.133844    0.001519     60.699193      52.076034
# 3888467    0.006082   17.139117    0.001282     45.368313      52.076034
# 3888468    0.008677    7.688285    0.001809     68.510277      63.439786
#
#         EcartNumCheq  NbrMagasin3J  DiffDateTr1  DiffDateTr2  DiffDateTr3  \
# 0                  0             1     4.000000          4.0          4.0
# 1                  1             2     1.797685          4.0          4.0
# 2                  0             1     4.000000          4.0          4.0
# 3                  0             1     4.000000          4.0          4.0
# 4                  1             1     1.997106          4.0          4.0
# ...              ...           ...          ...          ...          ...
# 3888464            0             1     4.000000          4.0          4.0
# 3888465            0             1     4.000000          4.0          4.0
# 3888466            0             1     4.000000          4.0          4.0
# 3888467            1             1     2.040174          4.0          4.0
# 3888468            0             1     4.000000          4.0          4.0
#
#          CA3TRetMtt   CA3TR  Heure  JourSemaine
# 0             20.00    0.00  27134            2
# 1             28.61    8.61  27817            2
# 2             57.64    0.00  28058            2
# 3             54.29    0.00  28128            2
# 4             59.15   32.25  29607            2
# ...             ...     ...    ...          ...
# 3888464      137.90    0.00  77684            2
# 3888465       73.76    0.00  78875            2
# 3888466       61.21    0.00  78896            2
# 3888467      304.50  245.60  78917            2
# 3888468       24.99    0.00  79080            2
#
# [3888468 rows x 19 columns]

# %%
scaler = StandardScaler()

# %%
# Scale only the selected columns and reconcatenante the full data matrix
X_train_scaled_part = scaler.fit_transform(X_train[cols_to_scale])
X_train_scaled_part = pd.DataFrame(X_train_scaled_part, columns=cols_to_scale, index=X_train.index)
X_train_scaled = pd.concat([X_train_scaled_part, X_train[cols_to_keep]], axis=1)

# %%
# X_test scaling
X_test_scaled_part = scaler.transform(X_test[cols_to_scale])
X_test_scaled_part = pd.DataFrame(X_test_scaled_part, columns=cols_to_scale, index=X_test.index)
X_test_scaled = pd.concat([X_test_scaled_part, X_test[cols_to_keep]], axis=1)

# %% [markdown]
# # Landmarks approximation

# %% [markdown]
# ## Functions preparation

# %%
def select_landmarks(X, n_landmarks, method="random", random_state=42):
    """
    Select landmarks into dataset X.

    Parameters:
    -----------
    X : array (n_samples, n_features)
    n_landmarks : int
        Number of landmarks to select
    method : str
        'random' or 'kmeans'
    """
    if method == "random":
        np.random.seed(random_state)
        indices = np.random.choice(X.shape[0], n_landmarks, replace=False)
        return X[indices], indices

    elif method == "kmeans":
        kmeans = KMeans(n_clusters=n_landmarks, random_state=random_state, n_init=10)
        kmeans.fit(X)
        # Landmarks are the cluster centers
        return kmeans.cluster_centers_, None

    else:
        raise ValueError("Méthode inconnue. Utilisez 'random' ou 'kmeans'.")

# %%
def kernel_approximation(X, landmarks, kernel_type="gaussian", gamma=1.0):
    """
    Project data X into the kernel space defined by the landmarks.
    
    Each point becomes a vector of similarities with all landmarks.
    
    Returns:
    --------
    X_transformed : array (n_samples, n_landmarks)
    """
    if kernel_type == "gaussian":
        # For each point in X, compute similarity to each landmark
        return rbf_kernel(X, landmarks, gamma=gamma)
    elif kernel_type == "linear":
        return linear_kernel(X, landmarks)
    else:
        raise ValueError("kernel_type doit être 'gaussian' ou 'linear'")

# %% [markdown]
# ## Landmarks approximation

# %% [markdown]
# ## Selecting landmarks

# %%
# n landmarks selection (using square root rule)
n_landmarks = 400
# Out:
# np.int64(1971)

# %%
landmarks = select_landmarks(
    X_train_scaled.values, n_landmarks=n_landmarks, method="kmeans")[0]

# %%
# Save landmarks
with open("../data/landmarks_svm_2k.pkl", "wb") as f:
    pickle.dump(landmarks, f)

# %% [markdown]
# ## Compute Gaussian kernel approximation

# %%
gamma = 0.1

X_train_transformed = kernel_approximation(X_train_scaled.values, landmarks, 
                                                   kernel_type="gaussian", gamma=gamma)

X_test_transformed = kernel_approximation(X_test_scaled.values, landmarks, 
                                            kernel_type="gaussian", gamma=gamma)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[28], line 3
#       1 gamma = 0.1
# ----> 3 X_train_transformed = kernel_approximation(X_train_scaled.values, landmarks,
#       4                                                    kernel_type="gaussian", gamma=gamma)
#       6 X_test_transformed = kernel_approximation(X_test_scaled.values, landmarks,
#       7                                             kernel_type="gaussian", gamma=gamma)
#
# Cell In[27], line 13, in kernel_approximation(X, landmarks, kernel_type, gamma)
#       2 """
#       3 Project data X into the kernel space defined by the landmarks.
#       4
#    (...)      9 X_transformed : array (n_samples, n_landmarks)
#      10 """
#      11 if kernel_type == "gaussian":
#      12     # For each point in X, compute similarity to each landmark
# ---> 13     return rbf_kernel(X, landmarks, gamma=gamma)
#      14 elif kernel_type == "linear":
#      15     return linear_kernel(X, landmarks)
#
# File c:\Users\axel-\Documents\Coding\SISE_FraudAnalysis\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\axel-\Documents\Coding\SISE_FraudAnalysis\.venv\Lib\site-packages\sklearn\metrics\pairwise.py:1612, in rbf_kernel(X, Y, gamma)
#    1609 if gamma is None:
#    1610     gamma = 1.0 / X.shape[1]
# -> 1612 K = euclidean_distances(X, Y, squared=True)
#    1613 K *= -gamma
#    1614 # exponentiate K in-place when using numpy
#
# File c:\Users\axel-\Documents\Coding\SISE_FraudAnalysis\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File c:\Users\axel-\Documents\Coding\SISE_FraudAnalysis\.venv\Lib\site-packages\sklearn\metrics\pairwise.py:371, in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     365     if Y_norm_squared.shape != (1, Y.shape[0]):
#     366         raise ValueError(
#     367             f"Incompatible dimensions for Y of shape {Y.shape} and "
#     368             f"Y_norm_squared of shape {original_shape}."
#     369         )
# --> 371 return _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#
# File c:\Users\axel-\Documents\Coding\SISE_FraudAnalysis\.venv\Lib\site-packages\sklearn\metrics\pairwise.py:407, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     404     distances = _euclidean_distances_upcast(X, XX, Y, YY)
#     405 else:
#     406     # if dtype is already float64, no need to chunk and upcast
# --> 407     distances = -2 * safe_sparse_dot(X, Y.T, dense_output=True)
#     408     distances += XX
#     409     distances += YY
#
# MemoryError: Unable to allocate 57.1 GiB for an array with shape (3888468, 1971) and data type float64

# %% [markdown]
# ## Train the SVM model with precomputed kernel
